# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# Set up the credentials for the Language Translator service
apikey = 'YOUR_API_KEY'
url = 'YOUR_URL'
authenticator = IAMAuthenticator(apikey)
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)
language_translator.set_service_url(url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from ibm_watson import LanguageTranslatorV3
#       2 from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
#       4 # Set up the credentials for the Language Translator service
#
# ModuleNotFoundError: No module named 'ibm_watson'

# %%
pip install ibm-watson
# Out:
#   Input In [1]
#     pip install ibm-watson
#         ^
# SyntaxError: invalid syntax

# %%
pip install ibm-watson
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.5/373.5 kB 34.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 21.5 MB/s eta 0:00:00
# ...
#   Created wheel for ibm-watson: filename=ibm_watson-6.1.0-py3-none-any.whl size=370763 sha256=01e551881ee20b746dfeaf79ea1a9fcf388dad7fb0a7af3275c532d5fcc37df3
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/18/ff/b2/6eab1b86aca7bb7bb3dba74b8fcfd2895549996fda84a854c9
# Successfully built ibm-watson
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# Set up the credentials for the Language Translator service
apikey = 'YOUR_API_KEY'
url = 'YOUR_URL'
authenticator = IAMAuthenticator(apikey)
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)
language_translator.set_service_url(url)

# %%
DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0
#
# NameError: name 'DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0' is not defined

# %%
language_translator = LanguageTranslatorV3(version='2018-05-01', 
    iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 language_translator = LanguageTranslatorV3(version='2018-05-01',
#       2     iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
#
# TypeError: LanguageTranslatorV3.__init__() got an unexpected keyword argument 'iam_apikey'

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

language_translator.set_service_url('https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')

# %%
language_translator = LanguageTranslatorV3(version='2018-05-01', 
    iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 language_translator = LanguageTranslatorV3(version='2018-05-01',
#       2     iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
#
# TypeError: LanguageTranslatorV3.__init__() got an unexpected keyword argument 'iam_apikey'

# %%
# !pip install --upgrade ibm-watson

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

language_translator.set_service_url('https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')

# %%
language_translator = LanguageTranslatorV3(version='2018-05-01', 
    iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 language_translator = LanguageTranslatorV3(version='2018-05-01',
#       2     iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
#
# TypeError: LanguageTranslatorV3.__init__() got an unexpected keyword argument 'iam_apikey'

# %%
# !pip install --upgrade ibm-watson

# %%
language_translator = LanguageTranslatorV3(version='2018-05-01', 
    iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 language_translator = LanguageTranslatorV3(version='2018-05-01',
#       2     iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
#
# TypeError: LanguageTranslatorV3.__init__() got an unexpected keyword argument 'iam_apikey'

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

language_translator.set_service_url('https://api.eu-gb.language-translator.watson.cloud.ibm.com')

# %%
anguage_translator = LanguageTranslatorV3(version='2018-05-01', 
    iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 anguage_translator = LanguageTranslatorV3(version='2018-05-01',
#       2     iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com')
#
# TypeError: LanguageTranslatorV3.__init__() got an unexpected keyword argument 'iam_apikey'

# %%
language_translator = LanguageTranslatorV3(version='2018-05-01', 
    iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d'
# Out:
#   Input In [15]
#     iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d'
#                                                                                                                                                                               ^
# SyntaxError: incomplete input

# %%
language_translator = LanguageTranslatorV3(version='2018-05-01', 
    iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 language_translator = LanguageTranslatorV3(version='2018-05-01',
#       2     iam_apikey='DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0', url='https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/0801d996-c40a-482f-b962-8cd87455f39d')
#
# TypeError: LanguageTranslatorV3.__init__() got an unexpected keyword argument 'iam_apikey'

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)
language_translator.set_service_url('https://api.eu-gb.language-translator.watson.cloud.ibm.com')

# %%
translation = language_translator.translate(
    text='Hello, how are you?',
    source='en',
    target='es').get_result()
    
print(translation['translations'][0]['translation'])
# Out:
# Hola, ¿cómo estás?

# %%
translation_response = language_translator.translate(
    text='Bonjour, comment ça va?',
    source='fr',
    target='en'
).get_result()

print(translation_response['translations'][0]['translation'])
# Out:
# Hello, how is it?

# %%
translation = translator.translate(
    text='Hello, how are you?',
    source='en',
    target='fr'
).get_result()

print(translation['translations'][0]['translation'])
# Output: Bonjour, comment allez-vous ?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 translation = translator.translate(
#       2     text='Hello, how are you?',
#       3     source='en',
#       4     target='fr'
#       5 ).get_result()
#       7 print(translation['translations'][0]['translation'])
#
# NameError: name 'translator' is not defined

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# Replace with your own API key and URL
authenticator = IAMAuthenticator('DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

translator.set_service_url('https://api.eu-gb.language-translator.watson.cloud.ibm.com')

# %%
translation = translator.translate(
    text='Hello, how are you?',
    source='en',
    target='fr'
).get_result()

print(translation['translations'][0]['translation'])
# Output: Bonjour, comment allez-vous ?
# Out:
# Bonjour, comment es-tu?

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('Bc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

translator.set_service_url('https://api.eu-gb.language-translator.watson.cloud.ibm.com')

# %%
translation = translator.translate(
    text='አማርኛ በአማርኛ ናቸው',
    source='am',
    target='en'
).get_result()

print(translation['translations'][0]['translation'])
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 translation = translator.translate(
#       2     text='አማርኛ በአማርኛ ናቸው',
#       3     source='am',
#       4     target='en'
#       5 ).get_result()
#       7 print(translation['translations'][0]['translation'])
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/ibm_watson/language_translator_v3.py:190, in LanguageTranslatorV3.translate(self, text, model_id, source, target, **kwargs)
#     187 headers['Accept'] = 'application/json'
#     189 url = '/v3/translate'
# --> 190 request = self.prepare_request(method='POST',
#     191                                url=url,
#     192                                headers=headers,
#     193                                params=params,
#     194                                data=data)
# ...

# %%
translation = translator.translate(
    text='Hello, how are you?',
    source='en',
    target='am'
).get_result()

print(translation['translations'][0]['translation'])
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 translation = translator.translate(
#       2     text='Hello, how are you?',
#       3     source='en',
#       4     target='am'
#       5 ).get_result()
#       7 print(translation['translations'][0]['translation'])
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/ibm_watson/language_translator_v3.py:190, in LanguageTranslatorV3.translate(self, text, model_id, source, target, **kwargs)
#     187 headers['Accept'] = 'application/json'
#     189 url = '/v3/translate'
# --> 190 request = self.prepare_request(method='POST',
#     191                                url=url,
#     192                                headers=headers,
#     193                                params=params,
#     194                                data=data)
# ...

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

translator.set_service_url('https://api.eu-gb.language-translator.watson.cloud.ibm.com')

# %%
translation = translator.translate(
    text='Hello, how are you?',
    source='en',
    target='am'
).get_result()

print(translation['translations'][0]['translation'])
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 translation = translator.translate(
#       2     text='Hello, how are you?',
#       3     source='en',
#       4     target='am'
#       5 ).get_result()
#       7 print(translation['translations'][0]['translation'])
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/ibm_watson/language_translator_v3.py:196, in LanguageTranslatorV3.translate(self, text, model_id, source, target, **kwargs)
#     189 url = '/v3/translate'
#     190 request = self.prepare_request(method='POST',
#     191                                url=url,
#     192                                headers=headers,
#     193                                params=params,
#     194                                data=data)
# --> 196 response = self.send(request, **kwargs)
#     197 return response
#
# ...

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('<apikey>')
translator = LanguageTranslatorV3(
    version='<version>',
    authenticator=authenticator
)

translation_models = translator.list_models().get_result()
for model in translation_models['models']:
    print(model['model_id'], "- Source:", model['source'], "- Target:", model['target'])
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Input In [28], in <cell line: 10>()
#       4 authenticator = IAMAuthenticator('<apikey>')
#       5 translator = LanguageTranslatorV3(
#       6     version='<version>',
#       7     authenticator=authenticator
#       8 )
# ---> 10 translation_models = translator.list_models().get_result()
#      11 for model in translation_models['models']:
#      12     print(model['model_id'], "- Source:", model['source'], "- Target:", model['target'])
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/ibm_watson/language_translator_v3.py:326, in LanguageTranslatorV3.list_models(self, source, target, default, **kwargs)
#     323 headers['Accept'] = 'application/json'
#     325 url = '/v3/models'
# --> 326 request = self.prepare_request(method='GET',
#     327                                url=url,
# ...

# %%
ApiException                              Traceback (most recent call last)
Input In [29], in <cell line: 10>()
      4 authenticator = IAMAuthenticator('DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
      5 translator = LanguageTranslatorV3(
      6     version='<version>',
      7     authenticator=authenticator
      8 )
---> 10 translation_models = translator.list_models().get_result()
     11 for model in translation_models['models']:
     12     print(model['model_id'], "- Source:", model['source'], "- Target:", model['target'])

File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/ibm_watson/language_translator_v3.py:331, in LanguageTranslatorV3.list_models(self, source, target, default, **kwargs)
    325 url = '/v3/models'
    326 request = self.prepare_request(method='GET',
    327                                url=url,
    328                                headers=headers,
    329                                params=params)
--> 331 response = self.send(request, **kwargs)
    332 return response

File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/ibm_cloud_sdk_core/base_service.py:308, in BaseService.send(self, request, **kwargs)
    303                 result = response
    304         return DetailedResponse(response=result,
    305                                 headers=response.headers,
    306                                 status_code=response.status_code)
--> 308     raise ApiException(response.status_code, http_response=response)
    309 except requests.exceptions.SSLError:
    310     logging.exception(self.ERROR_MSG_DISABLE_SSL)

ApiException: Error: Forbidden, Code: 403 , X-global-transaction-id: 4b7eff7d-40de-439d-b040-7adc8e85da4d
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Input In [29], in <cell line: 10>()
#       4 authenticator = IAMAuthenticator('DBc_Cu8VfmSi8u7ETi46qBbs0Du15803C6eUxaVX0TY0')
#       5 translator = LanguageTranslatorV3(
#       6     version='<version>',
#       7     authenticator=authenticator
#       8 )
# ---> 10 translation_models = translator.list_models().get_result()
#      11 for model in translation_models['models']:
#      12     print(model['model_id'], "- Source:", model['source'], "- Target:", model['target'])
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/ibm_watson/language_translator_v3.py:331, in LanguageTranslatorV3.list_models(self, source, target, default, **kwargs)
#     325 url = '/v3/models'
#     326 request = self.prepare_request(method='GET',
#     327                                url=url,
# ...
